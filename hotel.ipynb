# %%
class hotel:
        
        def __init__(self):
            self.amount=0
            print("----------WELCOME TO THE GRAND HOTEL-----------")
            i=input("Enter your name:- ")
            print("Hotel:- Hello mr/mrs",i," i am from Grand hotel how can i help you ??")
            i2=input("You:- ")
            print("Hotel:- sure we have such type of rooms available:-")
        def rooms(self):
            print("1. Single bed Non AC")
            print("2. Single bed with AC")
            print("3. Double bed Non AC")
            print("4. Double bed with AC")
            print("5.exit")
            print("which type of room would you like to book ?")
            choice=input("Enter your choice:- ")
            if choice=="1":
                r1=int(input("for howmany days ?:- "))
                r1price=1500
                r1price=r1price*r1
                self.amount+=r1price
                print("room price=",r1price)
                self.menu()
                self.bill()
            elif choice=="2":
                r2=int(input("for howmany days ?"))
                r2price=2500
                r2price=r2price*r2
                self.amount+=r2price
                print("room price=",r2price)
                self.menu()
                self.bill()
            elif choice=="3":
                r3=int(input("for howmany days ?"))
                r3price=3500
                r3price=r3price*r3
                self.amount+=r3price
                print("room price=",r3price)
                self.menu()
                self.bill()
            elif choice=="4":
                r4=int(input("for howmany days ?"))
                r4price=4500
                r4price=r4price*r4
                self.amount+=r4price
                print("room price=",r4price)
                self.menu()
                self.bill()
            else:
                print("wrong choice:-")
       
        def menu(self):
            hotel=input("Do you want to have breakfast:- ")
            if(hotel=='y' or hotel=='yes'):
                print("1. Sandwich")
                print("2. Toast")
                print("3. Upma")
                print("4. Dosa")
                ch=input("what you want:-")
                if ch=="1":
                    saprice=50
                    self.amount+=saprice
                    print("sure sandwitch Rs",saprice)
                elif ch=="2":
                    tprice=20
                    self.amount+=tprice
                    print("sure Toast Rs",tprice)
                elif ch=="3":
                    uprice=65
                    self.amount+=uprice
                    print("sure Upma Rs",uprice)
                elif ch=="4":
                    dprice=60
                    self.amount+=dprice
                    print("sure Dosa Rs",dprice)
                else:
                    print("no problem ")
                    
            hotel1=input("Do you want to have lunch")
            if(hotel1=='y' or hotel=='yes'):
                print("1. Cholle puri")
                print("2. dal fry jeera rice")
                print("3. paneer masala and tandoori roti")
                print("4. paneer bhurji and nan roti")
                print("5. pulav and curry")
                ch1=input("what you want")
                if ch1=="1":
                    chprice=110
                    self.amount+=chprice
                    print("sure Cholle puri Rs:",chprice)
                elif ch1=="2":
                    dfprice=175
                    self.amount+=dfprice
                    print("sure dal fry and jeera rice Rs:",dfprice)
                elif ch1=="3":
                    pmprice=349
                    self.amount+=pmprice
                    print("sure paneer masala and tandoori roti Rs:",pmprice)
                elif ch1=="4":
                    pbprice=180
                    self.amount+=pbprice
                    print("sure Paneer bhurji and nan roti Rs:",pbprice)
                elif ch1=="5":
                    pcprice=150
                    self.amount+=pcprice
                    print("sure pulav and curry Rs:",pcprice)
                else:
                    print("no problem ")
                
            hotel2=input("Do you want to have dinner")
            if(hotel2=='y' or hotel=='yes'):
                print("1. paav bhaji")
                print("2. Spring roll")
                print("3. noodles and manchurian")
                print("4. italian cheez pizza ")
                ch2=input("what you want")
                if ch2=="1":
                    pprice=110
                    self.amount+=pprice
                    print("sure Rs:",pprice)
                elif ch2=="2":
                    srprice=175
                    self.amount+=srprice
                    print("sure Gujarati dish Rs",srprice)
                elif ch2=="3":
                    nmprice=349
                    self.amount+=nmprice
                    print("sure Italian dish Rs",nmprice)
                elif ch2=="4":
                    ipprice=180
                    print("sure Chinies dish Rs",ipprice)
                else:
                    print("no problem ")
        def bill(self):
            print("-------bill--------")
            print("amount=",self.amount)
ci=hotel()
ci.rooms()
# Out:
# ----------WELCOME TO THE GRAND HOTEL-----------
# Enter your name:- nishad
# Hotel:- Hello mr/mrs nishad  i am from Grand hotel how can i help you ??
# You:- book aroom
# Hotel:- sure we have such type of rooms available:-
# 1. Single bed Non AC
# 2. Single bed with AC
# 3. Double bed Non AC
# 4. Double bed with AC
# 5.exit
# which type of room would you like to book ?
# Enter your choice:- 3
# for howmany days ?20
# room price= 70000
# Do you want to have breakfast:- y
# 1. Sandwich
# 2. Toast
# 3. Upma
# 4. Dosa
# what you want:-3
# sure Upma Rs 65
# Do you want to have lunchy
# 1. Cholle puri
# 2. dal fry jeera rice
# 3. paneer masala and tandoori roti
# 4. paneer bhurji and nan roti
# 5. pulav and curry
# what you want3
# sure paneer masala and tandoori roti Rs: 349
# Do you want to have dinnery
# 1. paav bhaji
# 2. Spring roll
# 3. noodles and manchurian
# 4. italian cheez pizza
# what you want2
# sure Gujarati dish Rs 175
# -------bill--------
# amount= 70589

# %%
# Out:
# Running cells with 'c:\Users\nisha\AppData\Local\Programs\Python\Python311\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/nisha/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'
